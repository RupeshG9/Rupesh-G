# %% [markdown]
# # Assignment 15/12/2022

# %% [markdown]
# ## 1. WAP to accept an integer from the user and check whether it is an even or odd

# %% [markdown]
# s= int(input('enter number'))
# if s%2 == 0:
#     print('even')
#
# else:
#     print('odd')

# %% [markdown]
# # 2.WAP to accept a character from the user and check whether it is a capital letter or small letter. Assume user will input only alphabets

# %%
ch=input("please enter the character")
if "A"<=ch[0]<="Z":
    print("this character will be a capital one")
else:
    print("this character will be a small one")
# Out:
# please enter the character Rupesh
# this character will be a capital one

# %% [markdown]
# # 3.WAP to accept a character from the user and check whether it is a capital letter or small letter or a digit or some special symbol

# %% [markdown]
# ch = input("Enter Any Character : ")
# if((ch >= 'a' and ch <= 'z') or (ch >= 'A' and ch <= 'Z')):
#     print("The Given Character ", ch, "is an Alphabet")
# elif(ch >= '0' and ch <= '9'):
#     print("The Given Character ", ch, "is a Digit")
# else:
#     print("The Given Character ", ch, "is a Special Character")

# %% [markdown]
# # 4.WAP to accept 3 integers from the user and without using any logical operator and cascading of relational operators , find out the greatest number amongst them

# %% [markdown]
# X=int(input("enter first no"))
# y=int(input("enter second no"))
# z=int(input("enter third no"))
# if X>=y:
#     if X>=z:
#         print("first will be greatest")
# elif y>=X:
#     if y>=z:
#         print("second is a greatest")
# else:
#     print("third is a greaest")

# %% [markdown]
# # 5.Write a program to accept a string from the user and display it vertically but don’t display the vowels in it.

# %%
str = input("Write anything:")
i = 0
while i<len(str):
    if str[i] not in 'aeiou':
        print(str[i])
    i=i+1
# Out:
# Write anything: ghonmode
# g
# h
# n
# m
# d

# %% [markdown]
# # 6.Write a program to continuously accept integers from the user until the user types 0 and as soon as 0 is entered display sum of all the nos entered before 0

# %%
x=int(input("Enter the Number"))

# %% [markdown]
# # ●	Write a program to print the following pattern (3 X 4 pattern)

# %%
def pattern(n):
     for i in range(0,n):
         for j in range(3, n+2):
              print("* " , end="")
         print("\r")
pattern(n=4)
# Out:
# * * *
# * * *
# * * *
# * * *

# %% [markdown]
# # WAP to print pattern(Pyramid)

# %%
def pattern(n):
     for i in range(0,n):
         for j in range(0, i+1):
              print("* " , end="")
         print("\r")
pattern(n=4)
# Out:
# *
# * *
# * * *
# * * * *

# %% [markdown]
# # WAP to print pattern(reverse Pyramid)

# %% [markdown]
# rows = int(input("Enter the number of rows: "))
# for i in range(rows + 1, 0, -1):
#     for j in range(0, i - 1):
#         print("*", end=' ')
#     print(" ")

# %% [markdown]
# # ●	Write a program to accept an integer from the user and display all the numbers from 1 to that number. Repeat the process until the user enters 0.

# %% [markdown]
# # WAP to accept a year from the user and check whether it is a leap year or not.

# %%
year = int(input("Enter Year: "))
if year % 4 == 0 and year % 100 != 0:
    print(year, "is a Leap Year")
elif year % 100 == 0:
    print(year, "is not a Leap Year")
elif year % 400 ==0:
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter Year:  2017
# 2017 is not a Leap Year

# %% [markdown]
# # ●	You have to develop a number guessing game

# %%
import random
n = random.randrange(1,10)
guess = int(input("Enter any number: "))
while n!= guess:
    if guess < n:
        print("Too low")
        guess = int(input("Enter number again: "))
    elif guess > n:
        print("Too high!")
        guess = int(input("Enter number again: "))
    else:
      break
print("you guessed it right!!")
# Out:
# Enter any number:  6
# Too high!
# Enter number again:  9
# Too high!
# Enter number again:  2
# Too low
